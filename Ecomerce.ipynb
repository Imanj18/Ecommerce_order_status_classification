# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import tree
from sklearn.metrics import classification_report

# %%
df=pd.read_csv('E-Commerce.csv')
df
# Out:
#       CustomerID  Gender InvoiceDate  InvoiceNumber  ProductID  Quantity  \
# 0           9691  Female   1/01/2019       26088332         32         3
# 1           8327  Female   1/01/2019       95183269         34         1
# 2           6801    Male   1/01/2019       44769684         64         2
# 3           4406    Male   1/02/2019       12422351         41         2
# 4           1966    Male   1/03/2019       84352310         20         1
# ...          ...     ...         ...            ...        ...       ...
# 3594        1130    Male  12/29/2023       71920492         75         3
# 3595        8329    Male  12/30/2023       60510134          2         1
# 3596        8023    Male  12/31/2023       52697896          2         1
# 3597        8307    Male  12/31/2023       61266739         55         2
# 3598        4655  Female  12/31/2023       97344391         40         1
#
#       Price   Total OrderStatus        Country      TrafficSource  \
# 0     91.37  274.11   Completed          India       Social Media
# 1     48.24   48.24  In Process          India       Social Media
# 2     35.23   70.46   Completed  United States  Paid Advertisment
# 3     32.33   64.66   Completed    Philippines       Social Media
# 4     81.89   81.89   Completed         Brazil     Organic Search
# ...     ...     ...         ...            ...                ...
# 3594  32.34   97.02  In Process        Germany     Organic Search
# 3595  33.11   33.11   Completed  United States       Social Media
# 3596  33.11   33.11   Completed          India     Organic Search
# 3597  73.53  147.06  In Process    South Korea  Paid Advertisment
# 3598  89.85   89.85  In Process  United States     Organic Search
#
#       SessionDuration DeviceCategory   Device       OS  DeliveryRating  \
# 0                6.54       Computer   Laptop  Windows               2
# 1                5.01       Computer  Desktop  Windows               0
# 2                0.10       Computer  Desktop  Windows               1
# 3                1.95         Mobile   Tablet  Windows               4
# 4                9.15       Computer   Laptop  Windows               5
# ...               ...            ...      ...      ...             ...
# 3594             9.42       Computer  Desktop      Mac               0
# 3595             9.78       Computer   Laptop  Windows               4
# 3596             9.80       Computer   Laptop  Windows               3
# 3597             6.53       Computer   Laptop  Windows               0
# 3598             5.81       Computer   Laptop  Windows               0
#
#       ProductRating   Sales
# 0                 5  274.11
# 1                 0    0.00
# 2                 2   70.46
# 3                 4   64.66
# 4                 3   81.89
# ...             ...     ...
# 3594              0    0.00
# 3595              5   33.11
# 3596              5   33.11
# 3597              0    0.00
# 3598              0    0.00
#
# [3599 rows x 18 columns]

# %% [markdown]
# ## Data cleaning and checking

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3599 entries, 0 to 3598
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       3599 non-null   int64
#  1   Gender           3599 non-null   object
#  2   InvoiceDate      3599 non-null   object
#  3   InvoiceNumber    3599 non-null   int64
#  4   ProductID        3599 non-null   int64
#  5   Quantity         3599 non-null   int64
#  6   Price            3599 non-null   float64
#  7   Total            3599 non-null   float64
#  8   OrderStatus      3599 non-null   object
#  9   Country          3599 non-null   object
#  10  TrafficSource    3599 non-null   object
#  11  SessionDuration  3599 non-null   float64
#  12  DeviceCategory   3599 non-null   object
#  13  Device           3599 non-null   object
#  14  OS               3599 non-null   object
#  15  DeliveryRating   3599 non-null   int64
#  16  ProductRating    3599 non-null   int64
#  17  Sales            3599 non-null   float64
# dtypes: float64(4), int64(6), object(8)
# memory usage: 506.2+ KB

# %%
df.describe()
# Out:
#         CustomerID  InvoiceNumber    ProductID     Quantity        Price  \
# count  3599.000000   3.599000e+03  3599.000000  3599.000000  3599.000000
# mean   5526.962767   5.582117e+07    50.864962     2.000556    48.714571
# std    2586.425565   2.568169e+07    29.035862     0.813313    29.499165
# min    1111.000000   1.114055e+07     1.000000     1.000000     1.220000
# 25%    3288.000000   3.355699e+07    26.000000     1.000000    26.030000
# 50%    5546.000000   5.614293e+07    52.000000     2.000000    43.500000
# 75%    7777.000000   7.810160e+07    76.000000     3.000000    74.550000
# max    9998.000000   9.996354e+07   100.000000     3.000000    99.720000
#
#              Total  SessionDuration  DeliveryRating  ProductRating  \
# count  3599.000000      3599.000000     3599.000000    3599.000000
# mean     97.394143         4.992101        2.641011       2.653515
# std      74.421471         2.896605        2.181087       2.179732
# min       1.220000         0.010000        0.000000       0.000000
# 25%      37.610000         2.490000        0.000000       0.000000
# 50%      81.460000         4.930000        3.000000       4.000000
# 75%     147.060000         7.515000        5.000000       5.000000
# max     299.160000        10.000000        5.000000       5.000000
#
#              Sales
# count  3599.000000
# mean     61.185285
# std      75.880928
# min       0.000000
# 25%       0.000000
# 50%      31.260000
# 75%      98.040000
# max     299.160000

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'InvoiceDate', 'InvoiceNumber', 'ProductID',
#        'Quantity', 'Price', 'Total', 'OrderStatus', 'Country', 'TrafficSource',
#        'SessionDuration', 'DeviceCategory', 'Device', 'OS', 'DeliveryRating',
#        'ProductRating', 'Sales'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CustomerID         0
# Gender             0
# InvoiceDate        0
# InvoiceNumber      0
# ProductID          0
# Quantity           0
# Price              0
# Total              0
# OrderStatus        0
# Country            0
# TrafficSource      0
# SessionDuration    0
# DeviceCategory     0
# Device             0
# OS                 0
# DeliveryRating     0
# ProductRating      0
# Sales              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], errors='coerce')

# %%
df.OrderStatus.unique()
# Out:
# array(['Completed', 'In Process', 'Returned', 'Cancelled'], dtype=object)

# %% [markdown]
# ## Identifying the dependent and independet variabes
# #### Don’t drop features based on assumption. Run:
# #### Crosstab + percentage
# #### Feature importance check
# #### (Optional) Statistical tests

# %%
x=df.drop('OrderStatus',axis=1)
y=df['OrderStatus']

# %% [markdown]
# ##### CustomerID - Unique to each customer
# ##### InvoiceNumber — unique to each order
# ##### ProductID — may or may not help (depends on modelling strategy)

# %%
x.drop(['CustomerID','InvoiceNumber','ProductID', 'Gender','Device','OS'],axis=1, inplace=True)
x.columns
# Out:
# Index(['InvoiceDate', 'Quantity', 'Price', 'Total', 'Country', 'TrafficSource',
#        'SessionDuration', 'DeviceCategory', 'DeliveryRating', 'ProductRating',
#        'Sales'],
#       dtype='object')

# %% [markdown]
# #### Gender
# #####  Based on this data, Gender does not have a significant effect on OrderStatus.

# %%
g=pd.crosstab(df['Gender'], df['OrderStatus'], normalize='index')*100
g.round(0).astype(int)
# Out:
# OrderStatus  Cancelled  Completed  In Process  Returned
# Gender
# Female              13         61          19         6
# Male                12         63          18         7

# %% [markdown]
# #### TrafficSource
# ##### These percentage differences are minor, suggesting that TrafficSource has very little or no significant effect on OrderStatus.

# %%
t=pd.crosstab(df['TrafficSource'], df['OrderStatus'],normalize='index')*100
t.round(0).astype(int)
# Out:
# OrderStatus        Cancelled  Completed  In Process  Returned
# TrafficSource
# Organic Search            12         62          19         6
# Paid Advertisment         14         66          15         6
# Social Media              13         61          19         7

# %% [markdown]
# ##### after traing the data and checking the feature importances i have removed and then again trained the model to make my model efficent

# %%
x = x.drop(['DeviceCategory', 'Quantity','TrafficSource'], axis=1)

# %%
x = x.drop('Country', axis=1)

# %%
x=x.drop('Price', axis=1)

# %%
x=x.drop('InvoiceDate', axis=1)

# %%
x.columns
# Out:
# Index(['Total', 'SessionDuration', 'DeliveryRating', 'ProductRating', 'Sales'], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(x)

# %% [markdown]
# ### Stratifies Kfold

# %%
def get_score(model,x_train, x_test, y_train, y_test):
    model.fit(x_train,y_train)
    return model.score(x_test,y_test)

# %%
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Random Forest': RandomForestClassifier(),
    'SVM': SVC(),
    'Decision Tree': tree.DecisionTreeClassifier()
}
model_scores = {name: [] for name in models}

# %%
from sklearn.model_selection import StratifiedKFold
skf= StratifiedKFold(n_splits=4)
for train_index , test_index in skf.split(X,y):
    x_train, x_test,y_train, y_test = X[train_index], X[test_index], y.iloc[train_index], y.iloc[test_index]
    for name, model in models.items():
        model.fit(x_train, y_train)
        score = model.score(x_test, y_test)
        model_scores[name].append(score)
        y_pred=model.predict(x_test)   
        print(f"\n{name} Classification Report:")
        print(classification_report(y_test, y_pred, zero_division=0))
# Out:
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.00      0.00      0.00       114
#    Completed       1.00      1.00      1.00       562
#   In Process       0.49      1.00      0.66       166
#     Returned       0.00      0.00      0.00        58
#
#     accuracy                           0.81       900
#    macro avg       0.37      0.50      0.41       900
# weighted avg       0.72      0.81      0.75       900
#
#
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.28      0.27      0.28       114
#    Completed       1.00      1.00      1.00       562
#   In Process       0.43      0.50      0.46       166
#     Returned       0.19      0.12      0.15        58
#
#     accuracy                           0.76       900
#    macro avg       0.48      0.47      0.47       900
# weighted avg       0.75      0.76      0.75       900
#
#
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.00      0.00      0.00       114
#    Completed       1.00      1.00      1.00       562
#   In Process       0.49      1.00      0.66       166
#     Returned       0.00      0.00      0.00        58
#
#     accuracy                           0.81       900
#    macro avg       0.37      0.50      0.41       900
# weighted avg       0.72      0.81      0.75       900
#
#
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.33      0.32      0.33       114
#    Completed       1.00      1.00      1.00       562
#   In Process       0.44      0.41      0.42       166
#     Returned       0.14      0.17      0.15        58
#
#     accuracy                           0.75       900
#    macro avg       0.48      0.48      0.48       900
# weighted avg       0.76      0.75      0.75       900
#
#
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.00      0.00      0.00       114
#    Completed       1.00      1.00      1.00       561
#   In Process       0.49      1.00      0.66       167
#     Returned       0.00      0.00      0.00        58
#
#     accuracy                           0.81       900
#    macro avg       0.37      0.50      0.42       900
# weighted avg       0.71      0.81      0.75       900
#
#
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.25      0.24      0.24       114
#    Completed       1.00      1.00      1.00       561
#   In Process       0.44      0.52      0.48       167
#     Returned       0.13      0.07      0.09        58
#
#     accuracy                           0.75       900
#    macro avg       0.45      0.46      0.45       900
# weighted avg       0.74      0.75      0.75       900
#
#
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.00      0.00      0.00       114
#    Completed       1.00      1.00      1.00       561
#   In Process       0.49      1.00      0.66       167
#     Returned       0.00      0.00      0.00        58
#
#     accuracy                           0.81       900
#    macro avg       0.37      0.50      0.42       900
# weighted avg       0.71      0.81      0.75       900
#
#
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.28      0.32      0.30       114
#    Completed       1.00      1.00      1.00       561
#   In Process       0.44      0.38      0.41       167
#     Returned       0.12      0.14      0.13        58
#
#     accuracy                           0.74       900
#    macro avg       0.46      0.46      0.46       900
# weighted avg       0.75      0.74      0.75       900
#
#
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.00      0.00      0.00       115
#    Completed       1.00      1.00      1.00       561
#   In Process       0.49      1.00      0.66       166
#     Returned       0.00      0.00      0.00        58
#
#     accuracy                           0.81       900
#    macro avg       0.37      0.50      0.41       900
# weighted avg       0.71      0.81      0.74       900
#
#
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.29      0.26      0.28       115
#    Completed       1.00      1.00      1.00       561
#   In Process       0.44      0.52      0.48       166
#     Returned       0.15      0.10      0.12        58
#
#     accuracy                           0.76       900
#    macro avg       0.47      0.47      0.47       900
# weighted avg       0.75      0.76      0.76       900
#
#
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.00      0.00      0.00       115
#    Completed       1.00      1.00      1.00       561
#   In Process       0.49      1.00      0.66       166
#     Returned       0.00      0.00      0.00        58
#
#     accuracy                           0.81       900
#    macro avg       0.37      0.50      0.41       900
# weighted avg       0.71      0.81      0.74       900
#
#
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.32      0.32      0.32       115
#    Completed       1.00      1.00      1.00       561
#   In Process       0.45      0.45      0.45       166
#     Returned       0.16      0.17      0.17        58
#
#     accuracy                           0.76       900
#    macro avg       0.48      0.48      0.48       900
# weighted avg       0.76      0.76      0.76       900
#
#
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.00      0.00      0.00       114
#    Completed       1.00      1.00      1.00       561
#   In Process       0.49      1.00      0.66       166
#     Returned       0.00      0.00      0.00        58
#
#     accuracy                           0.81       899
#    macro avg       0.37      0.50      0.41       899
# weighted avg       0.71      0.81      0.75       899
#
#
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.32      0.30      0.31       114
#    Completed       1.00      1.00      1.00       561
#   In Process       0.47      0.57      0.51       166
#     Returned       0.13      0.07      0.09        58
#
#     accuracy                           0.77       899
#    macro avg       0.48      0.48      0.48       899
# weighted avg       0.76      0.77      0.76       899
#
#
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.00      0.00      0.00       114
#    Completed       1.00      1.00      1.00       561
#   In Process       0.49      1.00      0.66       166
#     Returned       0.00      0.00      0.00        58
#
#     accuracy                           0.81       899
#    macro avg       0.37      0.50      0.41       899
# weighted avg       0.71      0.81      0.75       899
#
#
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#    Cancelled       0.33      0.33      0.33       114
#    Completed       1.00      1.00      1.00       561
#   In Process       0.49      0.51      0.50       166
#     Returned       0.19      0.17      0.18        58
#
#     accuracy                           0.77       899
#    macro avg       0.50      0.50      0.50       899
# weighted avg       0.77      0.77      0.77       899

# %%
result_df=pd.DataFrame(model_scores)
result_df
# Out:
#    Logistic Regression  Random Forest       SVM  Decision Tree
# 0             0.808889       0.758889  0.808889       0.752222
# 1             0.808889       0.754444  0.808889       0.743333
# 2             0.807778       0.760000  0.807778       0.757778
# 3             0.808676       0.770857  0.808676       0.770857

# %% [markdown]
# #### Logistic & SVM: 🎯 Only predict Completed and In Process. Ignore others. ❌
# #### Random Forest: 👍 Predicts all classes, decent recall & macro F1. ✅
# #### Decision Tree: Close to Random Forest, does better on Returned. ✅

# %%
final_model = RandomForestClassifier( class_weight='balanced')
final_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
import joblib
joblib.dump(final_model, 'final_rf_model.pkl')
# Out:
# ['final_rf_model.pkl']

# %% [markdown]
# ##### It was the work done before the stratified k fold which was done, and the scores were not quite good, so to compare them after words we have done it, and we have gotten the best model and saved it.

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(x_test,y_test)
# Out:
# 0.7861111111111111

# %%
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
svm.score(x_test,y_test)
# Out:
# 0.8203703703703704

# %%
lr = LogisticRegression(max_iter=1000,class_weight='balanced')
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
dt = tree.DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
lr.score(x_test,y_test)
# Out:
# 0.7527777777777778

# %%
dt.score(x_test,y_test)
# Out:
# 0.7685185185185185

# %% [markdown]
# ### Feature Importance to eliminate irelevant variables

# %%
pd.Series(rf.feature_importances_, index=x.columns).sort_values(ascending=False)
# Out:
# DeliveryRating     0.230013
# SessionDuration    0.223017
# Total              0.198160
# Sales              0.174814
# ProductRating      0.173995
# dtype: float64
